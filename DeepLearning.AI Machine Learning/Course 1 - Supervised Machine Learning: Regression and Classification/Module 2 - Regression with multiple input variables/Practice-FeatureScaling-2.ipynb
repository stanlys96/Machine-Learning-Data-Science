# %%
import numpy as np
import matplotlib.pyplot as plt
from lab_utils_multi import  load_house_data, run_gradient_descent 
from lab_utils_multi import  norm_plot, plt_equal_scale, plot_cost_i_w
from lab_utils_common import dlc
import seaborn as sns
np.set_printoptions(precision=2)
plt.style.use('./deeplearning.mplstyle')

# %%
# load the dataset
X_train, y_train = load_house_data()
X_features = ['size(sqft)','bedrooms','floors','age']

# %%
def z_normalize_features(X):
    mu = np.mean(X, axis=0)
    sigma = np.std(X, axis=0)
    X_mean = X - mu
    X_norm = (X - mu) / sigma
    return X_norm, mu, sigma

# %%
X_norm, X_mu, X_sigma = z_normalize_features(X_train)

# %%
print(np.ptp(X_train, axis=0))
print(np.ptp(X_norm, axis=0))
# Out:
# [2.41e+03 4.00e+00 1.00e+00 9.50e+01]
# [5.85 6.14 2.06 3.69]

# %%
fig, ax = plt.subplots(1, X_train.shape[1], figsize=(12, 3), sharey=True)
for i in range(len(ax)):
    ax[i].scatter(X_train[:, i], y_train)
plt.show()

# %%
mu = np.mean(X_train, axis=0)
sigma = np.std(X_train, axis=0)
X_mean = X_train - mu
X_norm = (X_train - mu) / sigma
fig, ax = plt.subplots(1, 3, figsize=(12, 3))
ax[0].scatter(X_train[:, 0], X_train[:, 3])
ax[0].axis("equal")

ax[1].scatter(X_mean[:, 0], X_mean[:, 3])
ax[1].axis("equal")

ax[2].scatter(X_norm[:, 0], X_norm[:, 3])
ax[2].axis("equal")
plt.show()

# %%
fig, ax = plt.subplots(1, X_train.shape[1], figsize=(10, 6), sharey=True)
for i in range(len(ax)):
    sns.histplot(X_train[:, i], kde=True, ax=ax[i])
plt.show()
fig, ax = plt.subplots(1, X_norm.shape[1], figsize=(10, 6), sharey=True)
for i in range(len(ax)):
    sns.histplot(X_norm[:, i], kde=True, ax=ax[i])
plt.show()
