# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from lab_utils_multi import load_house_data
plt.style.use('./deeplearning.mplstyle')
np.set_printoptions(precision=2)

# %%
X_train = np.array([1.0, 2.0])   #features
y_train = np.array([300, 500])   #target value

# %%
lr = LinearRegression()
lr.fit(X_train.reshape(-1, 1), y_train)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [200.]
# 100.00000000000011

# %%
# load the dataset
X_train, y_train = load_house_data()
X_features = ['size(sqft)','bedrooms','floors','age']
scaler = StandardScaler()
X_norm = scaler.fit_transform(X_train)

# %%
lr = LinearRegression()
lr.fit(X_norm, y_train)
# lr.predict(X_norm)
print(lr.coef_)
print(lr.intercept_)
results = lr.predict(X_norm)
# Out:
# [110.56 -21.27 -32.71 -37.97]
# 363.1560808080808

# %%
n = X_norm.shape[1]
fig, ax = plt.subplots(1, n, sharey=True, figsize=(12, 3))
for i in range(n):
    ax[i].scatter(X_train[:, i], y_train, label="Actual")
    ax[i].scatter(X_train[:, i], results, label="Prediction", c="orange")
ax[0].legend()
plt.show()
