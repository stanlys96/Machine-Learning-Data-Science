# %%
import numpy as np
import importlib
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_common import dlc, plot_data
import plt_one_addpt_onclick
importlib.reload(plt_one_addpt_onclick)
from plt_one_addpt_onclick import plt_one_addpt_onclick
plt.style.use('./deeplearning.mplstyle')

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
plt.close('all')
pos = y_train == 1
neg = y_train == 0
fig, ax = plt.subplots(1, 2, figsize=(10, 3))

ax[0].scatter(x_train[pos], y_train[pos], marker="x", s=80, c="red")
ax[0].scatter(x_train[neg], y_train[neg], s=100)
ax[0].set_ylim(-0.08, 1.1)

pos = y_train2 == 1
neg = y_train2 == 0
ax[1].scatter(X_train2[pos, 0], X_train2[pos][:, 1], marker="x", s=80, c="red")
ax[1].scatter(X_train2[neg, 0], X_train2[neg][:, 1], s=100)
ax[1].set(xlim=(0, 4), ylim=(0, 4))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pos = y_train2 == 1
neg = y_train2 == 0
print(pos)
print(X_train2[pos, 0])
print(X_train2[pos][:, 0])
print(X_train2)
# Out:
# [False False False  True  True  True]
# [3. 2. 1.]
# [3. 2. 1.]
# [[0.5 1.5]
#  [1.  1. ]
#  [1.5 0.5]
#  [3.  0.5]
#  [2.  2. ]
#  [1.  2.5]]
